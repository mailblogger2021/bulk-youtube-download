# %%
! pip install TikTokApi

# %%
import geocoder
g = geocoder.ip('me')
print(g)

# %%
from TikTokApi import TikTokApi
import asyncio

async def trending_videos():
    async with TikTokApi() as api:
        # Fetch the trending videos as an async generator
        async for video in api.trending.videos(count=30):
            print(video)
            print(video.as_dict())  # Convert the video object to a dictionary

if __name__ == "__main__":
    asyncio.run(trending_videos())

# %%
import asyncio
from TikTokApi import TikTokApi

async def trending_videos():
    async with TikTokApi() as api:
        async for video in api.trending.videos(count=30):
            print(video)
            print(video.as_dict())

# Directly call the async function with await
await trending_videos()

# %%
import asyncio
from TikTokApi import TikTokApi

async def trending_videos():
    async with TikTokApi() as api:
        async for video in api.trending.videos(count=30):
            print(video)
            print(video.as_dict())

# Get the running loop and execute the async function
loop = asyncio.get_event_loop()
loop.run_until_complete(trending_videos())

# %%
from TikTokApi import TikTokApi
verifyFp="verify_YOUR_S_V_WEB_ID_COOKIE"
api = TikTokApi.get_instance(custom_verifyFp=verifyFp)
print(api.trending(count=1))

# %%
cookie_list = [
{
    "name": "__Secure-1PAPISID",
    "value": "QtNOsva8aWZfIPXK/AWXx95gIdMh9OXZMg",
    "domain": ".youtube.com",
    "hostOnly": False,
    "path": "/",
    "secure": True,
    "httpOnly": False,
    "sameSite": "no_restriction",
    "session": False,
    "firstPartyDomain": "",
    "partitionKey": None,
    "expirationDate": 1771250657,
    "storeId": "firefox-default",
    "id": 1
},
{
    "name": "__Secure-1PSID",
    "value": "g.a000sQgE5-SFYL5hP5vM_kmatXvsFYH93sO1U-Oj_uWUXPxrMPcOb316F6FRMa-qk_lWBZbyvwACgYKAYASARESFQHGX2Mi6TqHt1Kgc9DB2g1JorCMnRoVAUF8yKqgZlsprRXEXslNZ3C2azC-0076",
    "domain": ".youtube.com",
    "hostOnly": False,
    "path": "/",
    "secure": True,
    "httpOnly": True,
    "sameSite": "no_restriction",
    "session": False,
    "firstPartyDomain": "",
    "partitionKey": None,
    "expirationDate": 1771250657,
    "storeId": "firefox-default",
    "id": 2
},
{
    "name": "__Secure-1PSIDCC",
    "value": "AKEyXzWVLENZLeXDPVwjVpwHNeb4OR5wmhJHiQADE7ZhAxL6R4yROmRRFNxyYzjzjduF8frt",
    "domain": ".youtube.com",
    "hostOnly": False,
    "path": "/",
    "secure": True,
    "httpOnly": True,
    "sameSite": "no_restriction",
    "session": False,
    "firstPartyDomain": "",
    "partitionKey": None,
    "expirationDate": 1768309051,
    "storeId": "firefox-default",
    "id": 3
},
{
    "name": "__Secure-1PSIDTS",
    "value": "sidts-CjEBmiPuTYTaRuE_5kOQvyJk-EGsq36EgHZ7hw67F1bI18ZO9C4sPil7ol6W_UYAQOoTEAA",
    "domain": ".youtube.com",
    "hostOnly": False,
    "path": "/",
    "secure": True,
    "httpOnly": True,
    "sameSite": "no_restriction",
    "session": False,
    "firstPartyDomain": "",
    "partitionKey": None,
    "expirationDate": 1768308755,
    "storeId": "firefox-default",
    "id": 4
},
{
    "name": "__Secure-3PAPISID",
    "value": "QtNOsva8aWZfIPXK/AWXx95gIdMh9OXZMg",
    "domain": ".youtube.com",
    "hostOnly": False,
    "path": "/",
    "secure": True,
    "httpOnly": False,
    "sameSite": "no_restriction",
    "session": False,
    "firstPartyDomain": "",
    "partitionKey": None,
    "expirationDate": 1771250657,
    "storeId": "firefox-default",
    "id": 5
},
{
    "name": "__Secure-3PSID",
    "value": "g.a000sQgE5-SFYL5hP5vM_kmatXvsFYH93sO1U-Oj_uWUXPxrMPcOAnSawMRHyym67g1xS4ND-QACgYKARESARESFQHGX2MiW7VkUwC9I6VwBnMvbkP5xhoVAUF8yKphXF0QDAAPRduM6iCZVzWa0076",
    "domain": ".youtube.com",
    "hostOnly": False,
    "path": "/",
    "secure": True,
    "httpOnly": True,
    "sameSite": "no_restriction",
    "session": False,
    "firstPartyDomain": "",
    "partitionKey": None,
    "expirationDate": 1771250657,
    "storeId": "firefox-default",
    "id": 6
},
{
    "name": "__Secure-3PSIDCC",
    "value": "AKEyXzU-W0ys0DFS6MRzs35nY5Ju_QqTHLqkLX815JtE06r9Y5xlHt_VR3kOmAmC9ArNgMVy",
    "domain": ".youtube.com",
    "hostOnly": False,
    "path": "/",
    "secure": True,
    "httpOnly": True,
    "sameSite": "no_restriction",
    "session": False,
    "firstPartyDomain": "",
    "partitionKey": None,
    "expirationDate": 1768309051,
    "storeId": "firefox-default",
    "id": 7
},
{
    "name": "__Secure-3PSIDTS",
    "value": "sidts-CjEBmiPuTYTaRuE_5kOQvyJk-EGsq36EgHZ7hw67F1bI18ZO9C4sPil7ol6W_UYAQOoTEAA",
    "domain": ".youtube.com",
    "hostOnly": False,
    "path": "/",
    "secure": True,
    "httpOnly": True,
    "sameSite": "no_restriction",
    "session": False,
    "firstPartyDomain": "",
    "partitionKey": None,
    "expirationDate": 1768308755,
    "storeId": "firefox-default",
    "id": 8
},
{
    "name": "__Secure-ROLLOUT_TOKEN",
    "value": "CNrNgMbwtOXxZhDyv-_LrPCKAxjyv-_LrPCKAw%3D%3D",
    "domain": ".youtube.com",
    "hostOnly": False,
    "path": "/",
    "secure": True,
    "httpOnly": True,
    "sameSite": "no_restriction",
    "session": False,
    "firstPartyDomain": "",
    "partitionKey": None,
    "expirationDate": 1752242585,
    "storeId": "firefox-default",
    "id": 9
},
{
    "name": "APISID",
    "value": "ZdCBYpQlE1muXVHr/A1BDp87nTvKzfmrYF",
    "domain": ".youtube.com",
    "hostOnly": False,
    "path": "/",
    "secure": False,
    "httpOnly": False,
    "sameSite": "no_restriction",
    "session": False,
    "firstPartyDomain": "",
    "partitionKey": None,
    "expirationDate": 1771250657,
    "storeId": "firefox-default",
    "id": 10
},
{
    "name": "GPS",
    "value": "1",
    "domain": ".youtube.com",
    "hostOnly": False,
    "path": "/",
    "secure": True,
    "httpOnly": True,
    "sameSite": "no_restriction",
    "session": False,
    "firstPartyDomain": "",
    "partitionKey": None,
    "expirationDate": 1736692385,
    "storeId": "firefox-default",
    "id": 11
},
{
    "name": "HSID",
    "value": "AbBUTY2-xvI1yj1Wl",
    "domain": ".youtube.com",
    "hostOnly": False,
    "path": "/",
    "secure": False,
    "httpOnly": True,
    "sameSite": "no_restriction",
    "session": False,
    "firstPartyDomain": "",
    "partitionKey": None,
    "expirationDate": 1771250657,
    "storeId": "firefox-default",
    "id": 12
},
{
    "name": "LOGIN_INFO",
    "value": "AFmmF2swRQIhAKsCUMbCNV14EBZeZoVJCP4x46QxHAZ81vPpFYLjpd0NAiAhG59liDl1sySRcWu_nDKapTa-rW7e5NxVIYr5HuAirQ:",
    "domain": ".youtube.com",
    "hostOnly": False,
    "path": "/",
    "secure": True,
    "httpOnly": True,
    "sameSite": "no_restriction",
    "session": False,
    "firstPartyDomain": "",
    "partitionKey": None,
    "expirationDate": 1771250686,
    "storeId": "firefox-default",
    "id": 13
},
{
    "name": "PREF",
    "value": "tz=Asia.Kolkata",
    "domain": ".youtube.com",
    "hostOnly": False,
    "path": "/",
    "secure": True,
    "httpOnly": False,
    "sameSite": "no_restriction",
    "session": False,
    "firstPartyDomain": "",
    "partitionKey": None,
    "expirationDate": 1771332752,
    "storeId": "firefox-default",
    "id": 14
},
{
    "name": "SAPISID",
    "value": "QtNOsva8aWZfIPXK/AWXx95gIdMh9OXZMg",
    "domain": ".youtube.com",
    "hostOnly": False,
    "path": "/",
    "secure": True,
    "httpOnly": False,
    "sameSite": "no_restriction",
    "session": False,
    "firstPartyDomain": "",
    "partitionKey": None,
    "expirationDate": 1771250657,
    "storeId": "firefox-default",
    "id": 15
},
{
    "name": "SID",
    "value": "g.a000sQgE5-SFYL5hP5vM_kmatXvsFYH93sO1U-Oj_uWUXPxrMPcOUItiF6I_8o-_b5QvM6sK6AACgYKAWcSARESFQHGX2Mi6w7y2pidYyWJ2QDV9_rydBoVAUF8yKrbE-ABVNNigS-itqrRSlRz0076",
    "domain": ".youtube.com",
    "hostOnly": False,
    "path": "/",
    "secure": False,
    "httpOnly": False,
    "sameSite": "no_restriction",
    "session": False,
    "firstPartyDomain": "",
    "partitionKey": None,
    "expirationDate": 1771250657,
    "storeId": "firefox-default",
    "id": 16
},
{
    "name": "SIDCC",
    "value": "AKEyXzXn9FNe9R8uwvB9PgpX52sOV_-clLQJhl1ZhqjqZviq1svsfPe4z_9Zr4-6gxDKSi2oNw",
    "domain": ".youtube.com",
    "hostOnly": False,
    "path": "/",
    "secure": False,
    "httpOnly": False,
    "sameSite": "no_restriction",
    "session": False,
    "firstPartyDomain": "",
    "partitionKey": None,
    "expirationDate": 1768309051,
    "storeId": "firefox-default",
    "id": 17
},
{
    "name": "SSID",
    "value": "AgMhJg0am92mc2IQy",
    "domain": ".youtube.com",
    "hostOnly": False,
    "path": "/",
    "secure": True,
    "httpOnly": True,
    "sameSite": "no_restriction",
    "session": False,
    "firstPartyDomain": "",
    "partitionKey": None,
    "expirationDate": 1771250657,
    "storeId": "firefox-default",
    "id": 18
},
{
    "name": "ST-1b",
    "value": "remind_identity=1",
    "domain": ".youtube.com",
    "hostOnly": False,
    "path": "/",
    "secure": True,
    "httpOnly": True,
    "sameSite": "no_restriction",
    "session": False,
    "firstPartyDomain": "",
    "partitionKey": None,
    "expirationDate": 1736690691,
    "storeId": "firefox-default",
    "id": 19
},
{
    "name": "ST-1tzw2b8",
    "value": "itct=CB8Q8qgHGAIiEwjquo_9rPCKAxXRpNgFHWZIA54%3D&csn=8kUwjcBddxIRfQY0&session_logininfo=AFmmF2swRQIhAKsCUMbCNV14EBZeZoVJCP4x46QxHAZ81vPpFYLjpd0NAiAhG59liDl1sySRcWu_nDKapTa-rW7e5NxVIYr5HuAirQ%%3D%3D&endpoint=%7B%22clickTrackingParams%22%3A%22CB8Q8qgHGAIiEwjquo_9rPCKAxXRpNgFHWZIA54%3D%22%2C%22commandMetadata%22%3A%7B%22webCommandMetadata%22%3A%7B%22url%22%3A%22%2Ffeed%2Fsubscriptions%22%2C%22webPageType%22%3A%22WEB_PAGE_TYPE_BROWSE%22%2C%22rootVe%22%3A96368%2C%22apiUrl%22%3A%22%2Fyoutubei%2Fv1%2Fbrowse%22%7D%7D%2C%22browseEndpoint%22%3A%7B%22browseId%22%3A%22FEsubscriptions%22%7D%7D",
    "domain": ".youtube.com",
    "hostOnly": False,
    "path": "/",
    "secure": False,
    "httpOnly": False,
    "sameSite": "no_restriction",
    "session": False,
    "firstPartyDomain": "",
    "partitionKey": None,
    "expirationDate": 1736690697,
    "storeId": "firefox-default",
    "id": 20
},
{
    "name": "ST-hcbf8d",
    "value": "session_logininfo=AFmmF2swRQIhAKsCUMbCNV14EBZeZoVJCP4x46QxHAZ81vPpFYLjpd0NAiAhG59liDl1sySRcWu_nDKapTa-rW7e5NxVIYr5HuAirQ%%3D%3D",
    "domain": ".youtube.com",
    "hostOnly": False,
    "path": "/",
    "secure": False,
    "httpOnly": False,
    "sameSite": "no_restriction",
    "session": False,
    "firstPartyDomain": "",
    "partitionKey": None,
    "expirationDate": 1736772757,
    "storeId": "firefox-default",
    "id": 21
},
{
    "name": "ST-l3hjtt",
    "value": "session_logininfo=AFmmF2swRQIhAKsCUMbCNV14EBZeZoVJCP4x46QxHAZ81vPpFYLjpd0NAiAhG59liDl1sySRcWu_nDKapTa-rW7e5NxVIYr5HuAirQ%%3D%3D",
    "domain": ".youtube.com",
    "hostOnly": False,
    "path": "/",
    "secure": False,
    "httpOnly": False,
    "sameSite": "no_restriction",
    "session": False,
    "firstPartyDomain": "",
    "partitionKey": None,
    "expirationDate": 1736772757,
    "storeId": "firefox-default",
    "id": 22
},
{
    "name": "ST-snvx7d",
    "value": "session_logininfo=AFmmF2swRQIgD3cKZelyq6iXMPRx3ZGTOGxzieQTHlcbZICPhfExeJcCIQCtUAwKMLwSoMTqvUFKhAgAC6mv8e1bwKA19NO1HvM1Lw%3AQUQ3MjNmd1pDNmhfclYtYklYS3FPc3VDQ2s5YkRZZDZOY01Mb3Vad2g1UjZBM2RqVXJfeEpIdjdHdWFFSXNiT21ocDk5UUtmVDJ5cnZxS3FfQnBHME04TW9MRVhEY016NVBHTVE0SEQ5eWk3Y05aaGJsTXdCckh6dnN4RERNVmZBUUc2dzJzWE83MUViNU1yNEdPbF9OUWZvdm9ZcDhJbG1n",
    "domain": ".youtube.com",
    "hostOnly": False,
    "path": "/",
    "secure": False,
    "httpOnly": False,
    "sameSite": "no_restriction",
    "session": False,
    "firstPartyDomain": "",
    "partitionKey": None,
    "expirationDate": 1736690668,
    "storeId": "firefox-default",
    "id": 23
},
{
    "name": "ST-tladcw",
    "value": "session_logininfo=AFmmF2swRQIhAKsCUMbCNV14EBZeZoVJCP4x46QxHAZ81vPpFYLjpd0NAiAhG59liDl1sySRcWu_nDKapTa-rW7e5NxVIYr5HuAirQ%%3D%3D",
    "domain": ".youtube.com",
    "hostOnly": False,
    "path": "/",
    "secure": False,
    "httpOnly": False,
    "sameSite": "no_restriction",
    "session": False,
    "firstPartyDomain": "",
    "partitionKey": None,
    "expirationDate": 1736772757,
    "storeId": "firefox-default",
    "id": 24
},
{
    "name": "ST-uwicob",
    "value": "session_logininfo=AFmmF2swRQIhAKsCUMbCNV14EBZeZoVJCP4x46QxHAZ81vPpFYLjpd0NAiAhG59liDl1sySRcWu_nDKapTa-rW7e5NxVIYr5HuAirQ%%3D%3D",
    "domain": ".youtube.com",
    "hostOnly": False,
    "path": "/",
    "secure": False,
    "httpOnly": False,
    "sameSite": "no_restriction",
    "session": False,
    "firstPartyDomain": "",
    "partitionKey": None,
    "expirationDate": 1736690711,
    "storeId": "firefox-default",
    "id": 25
},
{
    "name": "ST-xuwub9",
    "value": "session_logininfo=AFmmF2swRQIhAKsCUMbCNV14EBZeZoVJCP4x46QxHAZ81vPpFYLjpd0NAiAhG59liDl1sySRcWu_nDKapTa-rW7e5NxVIYr5HuAirQ%%3D%3D",
    "domain": ".youtube.com",
    "hostOnly": False,
    "path": "/",
    "secure": False,
    "httpOnly": False,
    "sameSite": "no_restriction",
    "session": False,
    "firstPartyDomain": "",
    "partitionKey": None,
    "expirationDate": 1736772759,
    "storeId": "firefox-default",
    "id": 26
},
{
    "name": "ST-yve142",
    "value": "session_logininfo=AFmmF2swRQIhAKsCUMbCNV14EBZeZoVJCP4x46QxHAZ81vPpFYLjpd0NAiAhG59liDl1sySRcWu_nDKapTa-rW7e5NxVIYr5HuAirQ%%3D%3D",
    "domain": ".youtube.com",
    "hostOnly": False,
    "path": "/",
    "secure": False,
    "httpOnly": False,
    "sameSite": "no_restriction",
    "session": False,
    "firstPartyDomain": "",
    "partitionKey": None,
    "expirationDate": 1736690709,
    "storeId": "firefox-default",
    "id": 27
},
{
    "name": "VISITOR_INFO1_LIVE",
    "value": "C3-dIHgh2FM",
    "domain": ".youtube.com",
    "hostOnly": False,
    "path": "/",
    "secure": True,
    "httpOnly": True,
    "sameSite": "no_restriction",
    "session": False,
    "firstPartyDomain": "",
    "partitionKey": None,
    "expirationDate": 1752324750,
    "storeId": "firefox-default",
    "id": 28
},
{
    "name": "VISITOR_PRIVACY_METADATA",
    "value": "CgJJThIEGgAgZg%3D%3D",
    "domain": ".youtube.com",
    "hostOnly": False,
    "path": "/",
    "secure": True,
    "httpOnly": True,
    "sameSite": "no_restriction",
    "session": False,
    "firstPartyDomain": "",
    "partitionKey": None,
    "expirationDate": 1752324750,
    "storeId": "firefox-default",
    "id": 29
},
{
    "name": "YSC",
    "value": "z20l95V0L0U",
    "domain": ".youtube.com",
    "hostOnly": False,
    "path": "/",
    "secure": True,
    "httpOnly": True,
    "sameSite": "no_restriction",
    "session": True,
    "firstPartyDomain": "",
    "partitionKey": None,
    "storeId": "firefox-default",
    "id": 30
}
]

# %%
from bot_studio import *
youtube=bot_studio.youtube()
false=False;true=True
cookie_list='list of cookies'
youtube.login_cookie(cookies=cookie_list)
response=youtube.upload(title='DataKund Uploading', video_path='C:/Users/user1/video1.mp4', kid_type="Yes, it's made for kids", description='It displays how to upload video to youtube using datakund', type='Public')
body=response['body']
video_link=body['VideoLink']
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from bot_studio import *
#       2 youtube=bot_studio.youtube()
#       3 false=False;true=True
#
# ModuleNotFoundError: No module named 'bot_studio'
